# %%
import xarray as xr
import glob
import rioxarray as rxr

# %%
path = r'D:/Research_Data/ISAT420/MODIS/MOD13C2_061-20260313_175141/'
files = glob.glob(f"{path}*.hdf")
files
# Out:
# ['D:/Research_Data/ISAT420/MODIS/MOD13C2_061-20260313_175141\\MOD13C2.A2000032.061.2020042083108.hdf',
#  'D:/Research_Data/ISAT420/MODIS/MOD13C2_061-20260313_175141\\MOD13C2.A2000061.061.2020041172815.hdf',
#  'D:/Research_Data/ISAT420/MODIS/MOD13C2_061-20260313_175141\\MOD13C2.A2000092.061.2020042094547.hdf',
#  'D:/Research_Data/ISAT420/MODIS/MOD13C2_061-20260313_175141\\MOD13C2.A2000122.061.2020045185153.hdf',
#  'D:/Research_Data/ISAT420/MODIS/MOD13C2_061-20260313_175141\\MOD13C2.A2000153.061.2020048051851.hdf',
#  'D:/Research_Data/ISAT420/MODIS/MOD13C2_061-20260313_175141\\MOD13C2.A2000183.061.2020051165038.hdf',
#  'D:/Research_Data/ISAT420/MODIS/MOD13C2_061-20260313_175141\\MOD13C2.A2000214.061.2020051032221.hdf',
#  'D:/Research_Data/ISAT420/MODIS/MOD13C2_061-20260313_175141\\MOD13C2.A2000245.061.2020052141316.hdf',
#  'D:/Research_Data/ISAT420/MODIS/MOD13C2_061-20260313_175141\\MOD13C2.A2000275.061.2020056031328.hdf',
# ...

# %%
rxr.open_rasterio(files[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\gerkentx\Anaconda3\envs\ISAT420_xr\Lib\site-packages\xarray\backends\file_manager.py:219, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     218 try:
# --> 219     file = self._cache[self._key]
#     220 except KeyError:
#
# File c:\Users\gerkentx\Anaconda3\envs\ISAT420_xr\Lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<function open at 0x0000022A0E276160>, ('D:/Research_Data/ISAT420/MODIS/MOD13C2_061-20260313_175141\\MOD13C2.A2000032.061.2020042083108.hdf',), 'r', (('sharing', False),), '3734f7c1-fea4-42fe-8bc7-5d555cacdd5f']
#
# During handling of the above exception, another exception occurred:
#
# ...
